# %% [markdown]
# Faz com que o Python mude o diretório de trabalho atual (current working directory, cwd) para a pasta que você especificou.

# %%
import os
os.chdir(r"C:\Users\Laura\Desktop\saeb_microdados_dashboard")

# %% [markdown]
# Importa todas as bibliotecas necessárias.

# %%
import pandas as pd
from src.ingestion.read_docente import read_docente
from src.cleaning.docente_cleaning import drop_colunas_problematicas_docente

# %% [markdown]
# Essas transformações garantem que os dados brutos se tornem um DataFrame **limpo, padronizado e legível**, pronto para análise exploratória, criação de indicadores e construção de dashboards.

# %%
df_docente = read_docente(1995)
df_docente = drop_colunas_problematicas_docente(df_docente)
df_docente.head()
# Out:
#     ano disc  estrato  upa  peso_tc  dep_adm  local  rede  uf  regiao  \
# 0  1995   4L        1  110        1      417      1     1   1      11
# 1  1995   8L        1  110        1      414      1     1   1      11
# 2  1995   8L        2  110        1      414      1     1   1      11
# 3  1995   3L        1  110        1      323      1     1   1      11
# 4  1995   4L        1  110        1      417      1     1   1      11
#
#    escolaridade  participou_cursos  horas_cursos  anos_magisterio  \
# 0          30.0                3.0           1.0              NaN
# 1          28.0                4.0           2.0              0.0
# 2          35.0                7.0           2.0              0.0
# 3          36.0                6.0           2.0              0.0
# 4          23.0                3.0           1.0             48.0
#
#    anos_docente  anos_escola  ingresso_concurso  vinculo_trabalhista  \
# 0           7.0          8.0                4.0                  1.0
# 1           9.0          9.0                8.0                  1.0
# 2           7.0          7.0                7.0                  2.0
# 3          10.0         11.0                1.0                  1.0
# 4           4.0          4.0                4.0                  1.0
#
#    carga_horaria  mes_salario  valor_salario  plano_nao_elaborou  \
# 0            2.0         40.0            9.0               325.0
# 1            1.0         40.0            9.0               430.0
# 2            2.0         20.0            NaN               388.0
# 3            2.0         40.0            NaN                 NaN
# 4            1.0         20.0            6.0                 NaN
#
#    plano_carga_horaria  plano_complexidade  plano_dominio  plano_distribuicao  \
# 0                    2                   1              2                   2
# 1                    2                   2              1                   2
# 2                    1                   2              2                   2
# 3                    2                   2              1                   1
# 4                    2                   2              2                   2
#
#    conteudo_desenvolvido  razao_conteudo  adotou_livro  alunos_com_livro  \
# 0                      2             3.0           1.0               1.0
# 1                      2             2.0           2.0               1.0
# 2                      2             3.0           1.0               1.0
# 3                      2             4.0           2.0               1.0
# 4                      1             2.0           2.0               1.0
#
#    aplica_provas  discute_resultados  licao_casa  corrige_licao  \
# 0            2.0                 2.0         2.0            1.0
# 1            2.0                 2.0         2.0            2.0
# 2            1.0                 1.0         2.0            2.0
# 3            2.0                 2.0         2.0            1.0
# 4            2.0                 1.0         2.0            1.0
#
#    procedimento_correcao  aprovacao_alunos  acao_medias_baixas  \
# 0                    1.0               3.0                 2.0
# 1                    1.0               1.0                 2.0
# 2                    1.0               1.0                 1.0
# 3                    1.0               2.0                 2.0
# 4                    1.0               1.0                 1.0
#
#    opiniao_aprendizagem  chama_pais  pais_atendem  participou_plano_trabalho  \
# 0                   3.0         2.0           1.0                        2.0
# 1                   1.0         1.0           1.0                        2.0
# 2                   3.0         1.0           2.0                        1.0
# 3                   1.0         1.0           2.0                        NaN
# 4                   3.0         1.0           1.0                        1.0
#
#    conselho_classe  reunioes_gestao  reuniao_analisa_dificuldades  \
# 0              3.0              2.0                           5.0
# 1              2.0              2.0                           2.0
# 2              2.0              2.0                           2.0
# 3              2.0              2.0                           4.0
# 4              1.0              2.0                           5.0
#
#    reuniao_discute_conteudo  reuniao_decide_aprovacao  \
# 0                         2                         2
# 1                         1                         2
# 2                         1                         1
# 3                         2                         2
# 4                         2                         2
#
#    reuniao_planos_conjuntos  reuniao_busca_solucoes  reuniao_nao_ocorreu  \
# 0                         2                       2                    2
# 1                         2                       2                    2
# 2                         1                       2                    1
# 3                         2                       2                    2
# 4                         2                       2                    2
#
#    apoio_pedagogico_escola  exigir_acompanhamento_pais  \
# 0                        1                         1.0
# 1                        2                         2.0
# 2                        2                         1.0
# 3                        1                         2.0
# 4                        1                         2.0
#
#    programa_recuperacao_paralela  capacitar_professores  \
# 0                              2                      2
# 1                              1                      2
# 2                              1                      2
# 3                              2                      2
# 4                              1                      2
#
#    melhorar_condicoes_fisicas  recurso_reprografia
# 0                           1                    2
# 1                           1                    1
# 2                           2                    1
# 3                           1                    2
# 4                           2                    2

# %%
df_docente.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4967 entries, 0 to 4966
# Data columns (total 55 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ano                            4967 non-null   int64
#  1   disc                           4967 non-null   str
#  2   estrato                        4967 non-null   int64
#  3   upa                            4967 non-null   int64
#  4   peso_tc                        4967 non-null   int64
#  5   dep_adm                        4967 non-null   int64
#  6   local                          4967 non-null   int64
#  7   rede                           4967 non-null   int64
#  8   uf                             4967 non-null   int64
#  9   regiao                         4967 non-null   int64
#  10  escolaridade                   4769 non-null   float64
#  11  participou_cursos              4809 non-null   float64
#  12  horas_cursos                   4966 non-null   float64
#  13  anos_magisterio                4719 non-null   float64
#  14  anos_docente                   4863 non-null   float64
#  15  anos_escola                    4800 non-null   float64
#  16  ingresso_concurso              4920 non-null   float64
#  17  vinculo_trabalhista            4192 non-null   float64
#  18  carga_horaria                  4114 non-null   float64
#  19  mes_salario                    4795 non-null   float64
#  20  valor_salario                  2759 non-null   float64
#  21  plano_nao_elaborou             4640 non-null   float64
#  22  plano_carga_horaria            4967 non-null   int64
#  23  plano_complexidade             4967 non-null   int64
#  24  plano_dominio                  4967 non-null   int64
#  25  plano_distribuicao             4967 non-null   int64
#  26  conteudo_desenvolvido          4967 non-null   int64
#  27  razao_conteudo                 4930 non-null   float64
#  28  adotou_livro                   4910 non-null   float64
#  29  alunos_com_livro               4882 non-null   float64
#  30  aplica_provas                  4936 non-null   float64
#  31  discute_resultados             4928 non-null   float64
#  32  licao_casa                     4902 non-null   float64
#  33  corrige_licao                  4935 non-null   float64
#  34  procedimento_correcao          4876 non-null   float64
#  35  aprovacao_alunos               4739 non-null   float64
#  36  acao_medias_baixas             4901 non-null   float64
#  37  opiniao_aprendizagem           4780 non-null   float64
#  38  chama_pais                     4793 non-null   float64
#  39  pais_atendem                   4891 non-null   float64
#  40  participou_plano_trabalho      4145 non-null   float64
#  41  conselho_classe                4842 non-null   float64
#  42  reunioes_gestao                4795 non-null   float64
#  43  reuniao_analisa_dificuldades   4828 non-null   float64
#  44  reuniao_discute_conteudo       4967 non-null   int64
#  45  reuniao_decide_aprovacao       4967 non-null   int64
#  46  reuniao_planos_conjuntos       4967 non-null   int64
#  47  reuniao_busca_solucoes         4967 non-null   int64
#  48  reuniao_nao_ocorreu            4967 non-null   int64
#  49  apoio_pedagogico_escola        4967 non-null   int64
#  50  exigir_acompanhamento_pais     4881 non-null   float64
#  51  programa_recuperacao_paralela  4967 non-null   int64
#  52  capacitar_professores          4967 non-null   int64
#  53  melhorar_condicoes_fisicas     4967 non-null   int64
#  54  recurso_reprografia            4967 non-null   int64
# dtypes: float64(30), int64(24), str(1)
# memory usage: 2.1 MB
